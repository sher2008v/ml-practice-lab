# %% [markdown]
# # Make Dataset

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv(r"C:\Users\Island\OneDrive\Desktop\ML Projects\ml-practice-lab\mobile-prices-classification\dataset\mobile_prices.csv")

# %% [markdown]
# ## Create a reduced dataset with the most important features
# ## And an all–features datataset

# %%
selected_features = data[['battery_power', 'px_height', 'px_width', 'ram', 'price_range']]

# %%
sf_x = selected_features.drop('price_range', axis=1)
sf_y = selected_features['price_range']
print(sf_x.sample(5))
print(sf_y.sample(5))
# Out:
#       battery_power  px_height  px_width   ram
# 1237           1558        322      1385   878
# 697            1567        545      1621  2312
# 279             823        630       888   294
# 11             1520        151      1005  3826
# 1769            733        950      1739   984
# 766     2
# 918     3
# 1731    0
# 1292    0
# 1293    2
# Name: price_range, dtype: int64

# %%
all_features = data.copy()

# %%
af_x = all_features.drop('price_range', axis=1)
af_y = all_features['price_range']
print(af_x.sample(5))
print(af_y.sample(5))
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 794             967     1          1.6         0   4       0          25
# 477             601     0          2.1         0   4       0          26
# 417             651     1          0.8         1   2       1          63
# 1572            895     0          0.5         1   6       0          16
# 1383           1763     0          0.5         1  12       0          10
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 794     0.6         92        8   9        243      1642  3076     7     4
# 477     0.3        101        4  18        509       548   918     9     1
# 417     0.2        176        5   4        548       858  2244    14     9
# 1572    0.3        164        8  14        126      1575  3122     7     0
# 1383    0.2        184        3  19        238      1893   792    17    12
#
#       talk_time  three_g  touch_screen  wifi
# 794          18        0             1     1
# 477          12        0             0     0
# 417          19        1             1     0
# 1572          4        0             0     1
# 1383         13        1             0     1
# 1588    2
# 1608    1
# 838     2
# 1690    3
# 28      2
# Name: price_range, dtype: int64
