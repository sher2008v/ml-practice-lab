# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## First EDA

# %%
data = pd.read_csv(r"C:\Users\Island\OneDrive\Desktop\ML Projects\ml-practice-lab\mobile-prices-classification\dataset\mobile_prices.csv")

# %%
data.sample(8)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1561           1076     0          2.3         1   0       1          14
# 1300            664     0          1.5         0   5       1           6
# 1454            832     1          0.5         0   5       1          22
# 759            1030     0          1.6         1   3       1          58
# 1120           1018     0          2.2         0   8       0          16
# 329             972     1          0.5         1   5       0          13
# 1966           1583     0          1.2         1   0       0          14
# 483            1476     0          0.5         0   0       1          43
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1561    0.7        191        5  ...       1088      1718  2355    17    16
# 1300    0.9        164        2  ...       1076      1472  3774    11     5
# 1454    0.6        198        1  ...        343      1431  1666    15     4
# 759     0.2        138        6  ...       1111      1812  2858     6     2
# 1120    0.6        153        8  ...        992      1433  3143    17    12
# 329     0.4        193        5  ...       1392      1795  1615    11     6
# 1966    0.2        148        2  ...       1171      1673  2498    13     6
# 483     0.7        148        2  ...       1789      1972  3644    15    10
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1561          2        1             1     1            2
# 1300         18        1             0     0            3
# 1454         20        1             1     1            1
# 759          18        1             1     1            3
# 1120         20        0             1     0            3
# 329          13        0             1     0            1
# 1966          8        0             0     1            2
# 483           6        1             0     1            3
#
# [8 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.3 KB

# %%
data['price_range'].value_counts()
# Out:
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64

# %%
data.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
corr = data.corr()
plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >
