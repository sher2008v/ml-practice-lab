# %% [markdown]
# # Make Dataset

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv(r"C:\Users\Island\OneDrive\Desktop\ML Projects\ml-practice-lab\mobile-prices-classification\dataset\mobile_prices.csv")

# %% [markdown]
# ## Create a reduced dataset with the most important features
# ## And an all–features datataset

# %%
selected_features = data[['battery_power', 'px_height', 'px_width', 'ram', 'price_range']]

# %%
sf_x = selected_features.drop('price_range', axis=1)
sf_y = selected_features['price_range']
print(sf_x.sample(5))
print(sf_y.sample(5))
# Out:
#       battery_power  px_height  px_width   ram
# 1175            563        211       684  3012
# 42             1253        685       714  1878
# 495            1066        401      1586  2728
# 1440           1134         18       903  3632
# 172             625        635       842  3323
# 1671    0
# 1719    0
# 1804    1
# 65      3
# 46      3
# Name: price_range, dtype: int64

# %%
all_features = data.copy()

# %%
af_x = all_features.drop('price_range', axis=1)
af_y = all_features['price_range']
print(af_x.sample(5))
print(af_y.sample(5))
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1393           1444     1          2.1         1   0       0           6
# 273            1611     1          0.5         1  11       0           3
# 107            1657     1          2.4         0   3       0          42
# 651            1762     1          2.5         0  10       1          15
# 1349           1576     1          0.9         1   0       1          14
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1393    0.9        103        1   1       1274      1340   712    17     5
# 273     0.6         98        3  14        303       714  1595     8     4
# 107     0.1        198        5  16       1770      1796  2597    18     1
# 651     0.3        107        8  11       1103      1364  2183     8     3
# 1349    0.4        173        2   4       1213      1386  3220    17     2
#
#       talk_time  three_g  touch_screen  wifi
# ...

# %%
sf_x.to_csv(r'C:\Users\Island\OneDrive\Desktop\ML Projects\ml-practice-lab\mobile-prices-classification\dataset\sf_x.csv', index=False)
sf_y.to_csv(r'C:\Users\Island\OneDrive\Desktop\ML Projects\ml-practice-lab\mobile-prices-classification\dataset\sf_y.csv', index=False)
af_x.to_csv(r'C:\Users\Island\OneDrive\Desktop\ML Projects\ml-practice-lab\mobile-prices-classification\dataset\af_x.csv', index=False)
af_y.to_csv(r'C:\Users\Island\OneDrive\Desktop\ML Projects\ml-practice-lab\mobile-prices-classification\dataset\af_y.csv', index=False)
